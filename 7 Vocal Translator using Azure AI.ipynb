# %% [markdown]
# # Voice translator with Azure AI
#
# <img src="https://github.com/retkowsky/azure-ai-translator/blob/main/webapp3.jpg?raw=true">

# %%
import datetime
import pandas as pd
import gradio as gr
import openai
import os
import sys

from azure.ai.translation.text import TextTranslationClient
from azure.core.credentials import AzureKeyCredential
from azure.ai.translation.text.models import InputTextItem
from dotenv import load_dotenv
from IPython.display import Audio
from openai import AzureOpenAI

# %%
sys.version
# Out:
# '3.10.14 (main, May  6 2024, 19:42:50) [GCC 11.2.0]'

# %%
print(f"Today is {datetime.datetime.today().strftime('%d-%b-%Y %H:%M:%S')}")
# Out:
# Today is 05-Mar-2025 11:21:53

# %% [markdown]
# ## 1. Settings

# %%
def check_openai_version():
    """
    Check OpenAI version
    """
    try:
        installed_version = openai.__version__
        version_number = float(installed_version.split('.')[0])

    except (AttributeError, ValueError):
        print("Invalid OpenAI version format")
        return

    print(f"Installed OpenAI version: {installed_version}\n")

    if version_number < 1.0:
        print("[Warning] You should upgrade OpenAI to have version >= 1.0.0")
        print("To upgrade, run: %pip install openai --upgrade")

    else:
        print(f"[OK] OpenAI version {installed_version} is greater than version 1.0.0")

# %%
check_openai_version()
# Out:
# Installed OpenAI version: 1.61.1
#
# [OK] OpenAI version 1.61.1 is greater than version 1.0.0

# %%
load_dotenv("azure.env")

# Azure AI Translator
azure_ai_translator_key = os.getenv("AZURE_AI_TRANSLATION_KEY")
azure_ai_translator_endpoint = os.getenv("AZURE_AI_TRANSLATION_ENDPOINT")
azure_ai_translator_region = os.getenv("AZURE_AI_TRANSLATION_REGION")

# Azure OpenAI Whisper model
openai.api_base = os.getenv("AOAI_ENDPOINT")
openai.api_key = os.getenv("AOAI_KEY")
openai.api_version = os.getenv("AOAI_VERSION")
openai.api_type = os.getenv("AOAI_TYPE")
deployment_id = os.getenv("AOAI_DEPLOYMENT")  # Whisper deployed name model
model = os.getenv("AOAI_MODEL")  # Whisper model

# %%
# Azure OpenAI Whisper client
aoai_client = AzureOpenAI(
    api_key=openai.api_key,
    api_version=openai.api_version,
    azure_endpoint=openai.api_base,
)

# %% [markdown]
# ## 2. Speech to text with Azure OpenAI Whisper

# %%
def speech_to_text_whisper(audio_filename):
    """
    Transcribes speech from an audio file using Azure Speech to Text service.
    Input: audio file
    Output: text transcript
    """
    try:
        with open(audio_filename, "rb") as audio_file:
            result = aoai_client.audio.transcriptions.create(
                file=audio_file,
                model=deployment_id
            )
            return result.text

    except Exception as e:
        print(f"[Error] Speech to text error: {e}")
        return None

# %%
audio_filename = "sample.wav"

# %%
Audio(audio_filename, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 2.1 Test

# %%
# Test
results = speech_to_text_whisper(audio_filename)
print(results)
# Out:
# Hello. How are you today?

# %% [markdown]
# ### 2.2 Speech to Text webapp

# %%
title = "Speech to Text with Azure OpenAI Whisper"
image_url = "https://github.com/retkowsky/azure-ai-translator/blob/main/logotranslate.png?raw=true"
logo = "<center> <img src= {} width=200px></center>".format(image_url)

stt_webapp = gr.Interface(
    speech_to_text_whisper,
    gr.Audio(sources="microphone", type="filepath", label="Audio Recording"),
    outputs=gr.Text(label="Text"),
    title=title,
    description=logo,
)

# %%
stt_webapp.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://a48e2fbacf962b5f73.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a48e2fbacf962b5f73.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## 3. Languages supported

# %%
credential = AzureKeyCredential(azure_ai_translator_key)

text_translator = TextTranslationClient(
    credential=credential,
    region=azure_ai_translator_region
)

# %%
def print_languages(label, languages):
        """
        Print supported languages
        """
        print("\033[1;31;34m")
        if languages is not None:
            print(f"Number of supported {label} languages = {len(languages)}\n")
            print(f"{label.capitalize()} languages:")

            for idx, (key, value) in enumerate(languages.items(), start=1):
                print(f"{idx:03}\t{key:10} {value.name} ({value.native_name})")

        else:
            print(f"No supported {label} languages.")

# %%
response = text_translator.get_supported_languages()

# %%
print_languages("translation", response.translation)
# Out:
# Number of supported translation languages = 135
#
# Translation languages:
# 001	af         Afrikaans (Afrikaans)
# 002	am         Amharic (አማርኛ)
# 003	ar         Arabic (العربية)
# 004	as         Assamese (অসমীয়া)
# 005	az         Azerbaijani (Azərbaycan)
# 006	ba         Bashkir (Bashkir)
# 007	bg         Bulgarian (Български)
# 008	bho        Bhojpuri (भोजपुरी)
# 009	bn         Bangla (বাংলা)
# 010	bo         Tibetan (བོད་སྐད་)
# 011	brx        Bodo (बड़ो)
# 012	bs         Bosnian (Bosanski)
# 013	ca         Catalan (Català)
# 014	cs         Czech (Čeština)
# 015	cy         Welsh (Cymraeg)
# 016	da         Danish (Dansk)
# 017	de         German (Deutsch)
# 018	doi        Dogri (डोगरी)
# 019	dsb        Lower Sorbian (Dolnoserbšćina)
# 020	dv         Divehi (ދިވެހިބަސް)
# 021	el         Greek (Ελληνικά)
# 022	en         English (English)
# 023	es         Spanish (Español)
# 024	et         Estonian (Eesti)
# 025	eu         Basque (Euskara)
# 026	fa         Persian (فارسی)
# 027	fi         Finnish (Suomi)
# 028	fil        Filipino (Filipino)
# 029	fj         Fijian (Na Vosa Vakaviti)
# 030	fo         Faroese (Føroyskt)
# 031	fr         French (Français)
# 032	fr-CA      French (Canada) (Français (Canada))
# 033	ga         Irish (Gaeilge)
# 034	gl         Galician (Galego)
# 035	gom        Konkani (कोंकणी)
# 036	gu         Gujarati (ગુજરાતી)
# 037	ha         Hausa (Hausa)
# 038	he         Hebrew (עברית)
# 039	hi         Hindi (हिन्दी)
# 040	hne        Chhattisgarhi (छत्तीसगढ़ी)
# 041	hr         Croatian (Hrvatski)
# 042	hsb        Upper Sorbian (Hornjoserbšćina)
# 043	ht         Haitian Creole (Haitian Creole)
# 044	hu         Hungarian (Magyar)
# 045	hy         Armenian (Հայերեն)
# 046	id         Indonesian (Indonesia)
# 047	ig         Igbo (Ásụ̀sụ́ Ìgbò)
# 048	ikt        Inuinnaqtun (Inuinnaqtun)
# 049	is         Icelandic (Íslenska)
# 050	it         Italian (Italiano)
# 051	iu         Inuktitut (ᐃᓄᒃᑎᑐᑦ)
# 052	iu-Latn    Inuktitut (Latin) (Inuktitut (Latin))
# 053	ja         Japanese (日本語)
# 054	ka         Georgian (ქართული)
# 055	kk         Kazakh (Қазақ Тілі)
# 056	km         Khmer (ខ្មែរ)
# 057	kmr        Kurdish (Northern) (Kurdî (Bakur))
# 058	kn         Kannada (ಕನ್ನಡ)
# 059	ko         Korean (한국어)
# 060	ks         Kashmiri (کٲشُر)
# 061	ku         Kurdish (Central) (Kurdî (Navîn))
# 062	ky         Kyrgyz (Кыргызча)
# 063	ln         Lingala (Lingála)
# 064	lo         Lao (ລາວ)
# 065	lt         Lithuanian (Lietuvių)
# 066	lug        Ganda (Ganda)
# 067	lv         Latvian (Latviešu)
# 068	lzh        Chinese (Literary) (中文 (文言文))
# 069	mai        Maithili (मैथिली)
# 070	mg         Malagasy (Malagasy)
# 071	mi         Māori (Te Reo Māori)
# 072	mk         Macedonian (Македонски)
# 073	ml         Malayalam (മലയാളം)
# 074	mn-Cyrl    Mongolian (Cyrillic) (Монгол)
# 075	mn-Mong    Mongolian (Traditional) (ᠮᠣᠩᠭᠣᠯ ᠬᠡᠯᠡ)
# 076	mni        Manipuri (ꯃꯩꯇꯩꯂꯣꯟ)
# 077	mr         Marathi (मराठी)
# 078	ms         Malay (Melayu)
# 079	mt         Maltese (Malti)
# 080	mww        Hmong Daw (Hmong Daw)
# 081	my         Myanmar (Burmese) (မြန်မာ)
# 082	nb         Norwegian (Norsk Bokmål)
# 083	ne         Nepali (नेपाली)
# 084	nl         Dutch (Nederlands)
# 085	nso        Sesotho sa Leboa (Sesotho sa Leboa)
# 086	nya        Nyanja (Nyanja)
# 087	or         Odia (ଓଡ଼ିଆ)
# 088	otq        Querétaro Otomi (Hñähñu)
# 089	pa         Punjabi (ਪੰਜਾਬੀ)
# 090	pl         Polish (Polski)
# 091	prs        Dari (دری)
# 092	ps         Pashto (پښتو)
# 093	pt         Portuguese (Brazil) (Português (Brasil))
# 094	pt-PT      Portuguese (Portugal) (Português (Portugal))
# 095	ro         Romanian (Română)
# 096	ru         Russian (Русский)
# 097	run        Rundi (Rundi)
# 098	rw         Kinyarwanda (Kinyarwanda)
# 099	sd         Sindhi (سنڌي)
# 100	si         Sinhala (සිංහල)
# 101	sk         Slovak (Slovenčina)
# 102	sl         Slovenian (Slovenščina)
# 103	sm         Samoan (Gagana Sāmoa)
# 104	sn         Shona (chiShona)
# 105	so         Somali (Soomaali)
# 106	sq         Albanian (Shqip)
# 107	sr-Cyrl    Serbian (Cyrillic) (Српски (ћирилица))
# 108	sr-Latn    Serbian (Latin) (Srpski (latinica))
# 109	st         Sesotho (Sesotho)
# 110	sv         Swedish (Svenska)
# 111	sw         Swahili (Kiswahili)
# 112	ta         Tamil (தமிழ்)
# 113	te         Telugu (తెలుగు)
# 114	th         Thai (ไทย)
# 115	ti         Tigrinya (ትግር)
# 116	tk         Turkmen (Türkmen Dili)
# 117	tlh-Latn   Klingon (Latin) (Klingon (Latin))
# 118	tlh-Piqd   Klingon (pIqaD) (Klingon (pIqaD))
# 119	tn         Setswana (Setswana)
# 120	to         Tongan (Lea Fakatonga)
# 121	tr         Turkish (Türkçe)
# 122	tt         Tatar (Татар)
# 123	ty         Tahitian (Reo Tahiti)
# 124	ug         Uyghur (ئۇيغۇرچە)
# 125	uk         Ukrainian (Українська)
# 126	ur         Urdu (اردو)
# 127	uz         Uzbek (Latin) (O‘Zbek)
# 128	vi         Vietnamese (Tiếng Việt)
# 129	xh         Xhosa (isiXhosa)
# 130	yo         Yoruba (Èdè Yorùbá)
# 131	yua        Yucatec Maya (Yucatec Maya)
# 132	yue        Cantonese (Traditional) (粵語 (繁體))
# 133	zh-Hans    Chinese Simplified (中文 (简体))
# 134	zh-Hant    Chinese Traditional (繁體中文 (繁體))
# 135	zu         Zulu (Isi-Zulu)

# %%
print_languages("transliteration", response.transliteration)
# Out:
# Number of supported transliteration languages = 42
#
# Transliteration languages:
# 001	ar         Arabic (العربية)
# 002	as         Assamese (অসমীয়া)
# 003	be         Belarusian (беларуская)
# 004	bg         Bulgarian (Български)
# 005	bn         Bangla (বাংলা)
# 006	brx        Bodo (बड़ो)
# 007	el         Greek (Ελληνικά)
# 008	fa         Persian (فارسی)
# 009	gom        Konkani (कोंकणी)
# 010	gu         Gujarati (ગુજરાતી)
# 011	he         Hebrew (עברית)
# 012	hi         Hindi (हिन्दी)
# 013	ja         Japanese (日本語)
# 014	kk         Kazakh (Қазақ Тілі)
# 015	kn         Kannada (ಕನ್ನಡ)
# 016	ko         Korean (한국어)
# 017	ks         Kashmiri (کٲشُر)
# 018	ky         Kyrgyz (Кыргызча)
# 019	mai        Maithili (मैथिली)
# 020	mk         Macedonian (Македонски)
# 021	ml         Malayalam (മലയാളം)
# 022	mn-Cyrl    Mongolian (Cyrillic) (Монгол)
# 023	mni        Manipuri (ꯃꯩꯇꯩꯂꯣꯟ)
# 024	mr         Marathi (मराठी)
# 025	ne         Nepali (नेपाली)
# 026	or         Odia (ଓଡ଼ିଆ)
# 027	pa         Punjabi (ਪੰਜਾਬੀ)
# 028	ru         Russian (Русский)
# 029	sa         Sanskrit (संस्कृत)
# 030	sd         Sindhi (سنڌي)
# 031	si         Sinhala (සිංහල)
# 032	sr-Cyrl    Serbian (Cyrillic) (Српски (ћирилица))
# 033	sr-Latn    Serbian (Latin) (Srpski (latinica))
# 034	ta         Tamil (தமிழ்)
# 035	te         Telugu (తెలుగు)
# 036	tg         Tajik (Тоҷикӣ)
# 037	th         Thai (ไทย)
# 038	tt         Tatar (Татар)
# 039	uk         Ukrainian (Українська)
# 040	ur         Urdu (اردو)
# 041	zh-Hans    Chinese Simplified (中文 (简体))
# 042	zh-Hant    Chinese Traditional (繁體中文 (繁體))

# %%
print_languages("dictionary", response.dictionary)
# Out:
# Number of supported dictionary languages = 50
#
# Dictionary languages:
# 001	af         Afrikaans (Afrikaans)
# 002	ar         Arabic (العربية)
# 003	bg         Bulgarian (Български)
# 004	bn         Bangla (বাংলা)
# 005	bs         Bosnian (Bosanski)
# 006	ca         Catalan (Català)
# 007	cs         Czech (Čeština)
# 008	cy         Welsh (Cymraeg)
# 009	da         Danish (Dansk)
# 010	de         German (Deutsch)
# 011	el         Greek (Ελληνικά)
# 012	en         English (English)
# 013	es         Spanish (Español)
# 014	et         Estonian (Eesti)
# 015	fa         Persian (فارسی)
# 016	fi         Finnish (Suomi)
# 017	fr         French (Français)
# 018	he         Hebrew (עברית)
# 019	hi         Hindi (हिन्दी)
# 020	hr         Croatian (Hrvatski)
# 021	hu         Hungarian (Magyar)
# 022	id         Indonesian (Indonesia)
# 023	is         Icelandic (Íslenska)
# 024	it         Italian (Italiano)
# 025	ja         Japanese (日本語)
# 026	ko         Korean (한국어)
# 027	lt         Lithuanian (Lietuvių)
# 028	lv         Latvian (Latviešu)
# 029	ms         Malay (Melayu)
# 030	mt         Maltese (Malti)
# 031	mww        Hmong Daw (Hmong Daw)
# 032	nb         Norwegian (Norsk Bokmål)
# 033	nl         Dutch (Nederlands)
# 034	pl         Polish (Polski)
# 035	pt         Portuguese (Brazil) (Português (Brasil))
# 036	ro         Romanian (Română)
# 037	ru         Russian (Русский)
# 038	sk         Slovak (Slovenčina)
# 039	sl         Slovenian (Slovenščina)
# 040	sr-Latn    Serbian (Latin) (Srpski (latinica))
# 041	sv         Swedish (Svenska)
# 042	sw         Swahili (Kiswahili)
# 043	ta         Tamil (தமிழ்)
# 044	th         Thai (ไทย)
# 045	tlh-Latn   Klingon (Latin) (Klingon (Latin))
# 046	tr         Turkish (Türkçe)
# 047	uk         Ukrainian (Українська)
# 048	ur         Urdu (اردو)
# 049	vi         Vietnamese (Tiếng Việt)
# 050	zh-Hans    Chinese Simplified (中文 (简体))

# %%
# Loading the supported languages into a dataframe
langlist = []

if response.translation is not None:
    for key, value in response.translation.items():
        langlist.append(
            {
                "Language_Code": key,
                "Language_Name": value.name,
                "Native_Name": value.native_name,
            }
        )

df_languages = pd.DataFrame(langlist)
df_languages
# Out:
#     Language_Code            Language_Name   Native_Name
# 0              af                Afrikaans     Afrikaans
# 1              am                  Amharic          አማርኛ
# 2              ar                   Arabic       العربية
# 3              as                 Assamese       অসমীয়া
# 4              az              Azerbaijani    Azərbaycan
# ..            ...                      ...           ...
# 130           yua             Yucatec Maya  Yucatec Maya
# 131           yue  Cantonese (Traditional)       粵語 (繁體)
# 132       zh-Hans       Chinese Simplified       中文 (简体)
# 133       zh-Hant      Chinese Traditional     繁體中文 (繁體)
# 134            zu                     Zulu      Isi-Zulu
#
# [135 rows x 3 columns]

# %%
print("Azure AI Translator supported languages")
print("\033[1;31;34m")
print(df_languages.to_string())
# Out:
# Azure AI Translator supported languages
#
#     Language_Code            Language_Name           Native_Name
# 0              af                Afrikaans             Afrikaans
# 1              am                  Amharic                  አማርኛ
# 2              ar                   Arabic               العربية
# 3              as                 Assamese               অসমীয়া
# 4              az              Azerbaijani            Azərbaycan
# 5              ba                  Bashkir               Bashkir
# 6              bg                Bulgarian             Български
# 7             bho                 Bhojpuri               भोजपुरी
# 8              bn                   Bangla                 বাংলা
# 9              bo                  Tibetan              བོད་སྐད་
# 10            brx                     Bodo                  बड़ो
# 11             bs                  Bosnian              Bosanski
# 12             ca                  Catalan                Català
# 13             cs                    Czech               Čeština
# 14             cy                    Welsh               Cymraeg
# 15             da                   Danish                 Dansk
# 16             de                   German               Deutsch
# 17            doi                    Dogri                 डोगरी
# 18            dsb            Lower Sorbian        Dolnoserbšćina
# 19             dv                   Divehi            ދިވެހިބަސް
# 20             el                    Greek              Ελληνικά
# 21             en                  English               English
# 22             es                  Spanish               Español
# 23             et                 Estonian                 Eesti
# 24             eu                   Basque               Euskara
# 25             fa                  Persian                 فارسی
# 26             fi                  Finnish                 Suomi
# 27            fil                 Filipino              Filipino
# 28             fj                   Fijian      Na Vosa Vakaviti
# 29             fo                  Faroese              Føroyskt
# 30             fr                   French              Français
# 31          fr-CA          French (Canada)     Français (Canada)
# 32             ga                    Irish               Gaeilge
# 33             gl                 Galician                Galego
# 34            gom                  Konkani                कोंकणी
# 35             gu                 Gujarati               ગુજરાતી
# 36             ha                    Hausa                 Hausa
# 37             he                   Hebrew                 עברית
# 38             hi                    Hindi                हिन्दी
# 39            hne            Chhattisgarhi            छत्तीसगढ़ी
# 40             hr                 Croatian              Hrvatski
# 41            hsb            Upper Sorbian       Hornjoserbšćina
# 42             ht           Haitian Creole        Haitian Creole
# 43             hu                Hungarian                Magyar
# 44             hy                 Armenian               Հայերեն
# 45             id               Indonesian             Indonesia
# 46             ig                     Igbo          Ásụ̀sụ́ Ìgbò
# 47            ikt              Inuinnaqtun           Inuinnaqtun
# 48             is                Icelandic              Íslenska
# 49             it                  Italian              Italiano
# 50             iu                Inuktitut                ᐃᓄᒃᑎᑐᑦ
# 51        iu-Latn        Inuktitut (Latin)     Inuktitut (Latin)
# 52             ja                 Japanese                   日本語
# 53             ka                 Georgian               ქართული
# 54             kk                   Kazakh            Қазақ Тілі
# 55             km                    Khmer                 ខ្មែរ
# 56            kmr       Kurdish (Northern)         Kurdî (Bakur)
# 57             kn                  Kannada                 ಕನ್ನಡ
# 58             ko                   Korean                   한국어
# 59             ks                 Kashmiri                 کٲشُر
# 60             ku        Kurdish (Central)         Kurdî (Navîn)
# 61             ky                   Kyrgyz              Кыргызча
# 62             ln                  Lingala               Lingála
# 63             lo                      Lao                   ລາວ
# 64             lt               Lithuanian              Lietuvių
# 65            lug                    Ganda                 Ganda
# 66             lv                  Latvian              Latviešu
# 67            lzh       Chinese (Literary)              中文 (文言文)
# 68            mai                 Maithili                मैथिली
# 69             mg                 Malagasy              Malagasy
# 70             mi                    Māori          Te Reo Māori
# 71             mk               Macedonian            Македонски
# 72             ml                Malayalam                മലയാളം
# 73        mn-Cyrl     Mongolian (Cyrillic)                Монгол
# 74        mn-Mong  Mongolian (Traditional)           ᠮᠣᠩᠭᠣᠯ ᠬᠡᠯᠡ
# 75            mni                 Manipuri               ꯃꯩꯇꯩꯂꯣꯟ
# 76             mr                  Marathi                 मराठी
# 77             ms                    Malay                Melayu
# 78             mt                  Maltese                 Malti
# 79            mww                Hmong Daw             Hmong Daw
# 80             my        Myanmar (Burmese)                မြန်မာ
# 81             nb                Norwegian          Norsk Bokmål
# 82             ne                   Nepali                नेपाली
# 83             nl                    Dutch            Nederlands
# 84            nso         Sesotho sa Leboa      Sesotho sa Leboa
# 85            nya                   Nyanja                Nyanja
# 86             or                     Odia                 ଓଡ଼ିଆ
# 87            otq          Querétaro Otomi                Hñähñu
# 88             pa                  Punjabi                ਪੰਜਾਬੀ
# 89             pl                   Polish                Polski
# 90            prs                     Dari                   دری
# 91             ps                   Pashto                  پښتو
# 92             pt      Portuguese (Brazil)    Português (Brasil)
# 93          pt-PT    Portuguese (Portugal)  Português (Portugal)
# 94             ro                 Romanian                Română
# 95             ru                  Russian               Русский
# 96            run                    Rundi                 Rundi
# 97             rw              Kinyarwanda           Kinyarwanda
# 98             sd                   Sindhi                  سنڌي
# 99             si                  Sinhala                 සිංහල
# 100            sk                   Slovak            Slovenčina
# 101            sl                Slovenian           Slovenščina
# 102            sm                   Samoan          Gagana Sāmoa
# 103            sn                    Shona              chiShona
# 104            so                   Somali              Soomaali
# 105            sq                 Albanian                 Shqip
# 106       sr-Cyrl       Serbian (Cyrillic)     Српски (ћирилица)
# 107       sr-Latn          Serbian (Latin)     Srpski (latinica)
# 108            st                  Sesotho               Sesotho
# 109            sv                  Swedish               Svenska
# 110            sw                  Swahili             Kiswahili
# 111            ta                    Tamil                 தமிழ்
# 112            te                   Telugu                తెలుగు
# 113            th                     Thai                   ไทย
# 114            ti                 Tigrinya                   ትግር
# 115            tk                  Turkmen          Türkmen Dili
# 116      tlh-Latn          Klingon (Latin)       Klingon (Latin)
# 117      tlh-Piqd          Klingon (pIqaD)       Klingon (pIqaD)
# 118            tn                 Setswana              Setswana
# 119            to                   Tongan         Lea Fakatonga
# 120            tr                  Turkish                Türkçe
# 121            tt                    Tatar                 Татар
# 122            ty                 Tahitian            Reo Tahiti
# 123            ug                   Uyghur              ئۇيغۇرچە
# 124            uk                Ukrainian            Українська
# 125            ur                     Urdu                  اردو
# 126            uz            Uzbek (Latin)                O‘Zbek
# 127            vi               Vietnamese            Tiếng Việt
# 128            xh                    Xhosa              isiXhosa
# 129            yo                   Yoruba            Èdè Yorùbá
# 130           yua             Yucatec Maya          Yucatec Maya
# 131           yue  Cantonese (Traditional)               粵語 (繁體)
# 132       zh-Hans       Chinese Simplified               中文 (简体)
# 133       zh-Hant      Chinese Traditional             繁體中文 (繁體)
# 134            zu                     Zulu              Isi-Zulu

# %%
df_languages.to_excel("azure_ai_translator_languages.xlsx")

# %%
# Get dict from dataframe
language_dict = df_languages.set_index("Language_Code")["Language_Name"].to_dict()
# Full names list
language_full_names = list(language_dict.values())
# Sort
language_full_names.sort()
# Language codes list
language_codes = list(language_dict.keys())
# Sort
language_codes.sort()
# Creation of dict
reverse_language_names = {v: k for k, v in language_dict.items()}

# %%
print(language_codes)
# Out:
# ['af', 'am', 'ar', 'as', 'az', 'ba', 'bg', 'bho', 'bn', 'bo', 'brx', 'bs', 'ca', 'cs', 'cy', 'da', 'de', 'doi', 'dsb', 'dv', 'el', 'en', 'es', 'et', 'eu', 'fa', 'fi', 'fil', 'fj', 'fo', 'fr', 'fr-CA', 'ga', 'gl', 'gom', 'gu', 'ha', 'he', 'hi', 'hne', 'hr', 'hsb', 'ht', 'hu', 'hy', 'id', 'ig', 'ikt', 'is', 'it', 'iu', 'iu-Latn', 'ja', 'ka', 'kk', 'km', 'kmr', 'kn', 'ko', 'ks', 'ku', 'ky', 'ln', 'lo', 'lt', 'lug', 'lv', 'lzh', 'mai', 'mg', 'mi', 'mk', 'ml', 'mn-Cyrl', 'mn-Mong', 'mni', 'mr', 'ms', 'mt', 'mww', 'my', 'nb', 'ne', 'nl', 'nso', 'nya', 'or', 'otq', 'pa', 'pl', 'prs', 'ps', 'pt', 'pt-PT', 'ro', 'ru', 'run', 'rw', 'sd', 'si', 'sk', 'sl', 'sm', 'sn', 'so', 'sq', 'sr-Cyrl', 'sr-Latn', 'st', 'sv', 'sw', 'ta', 'te', 'th', 'ti', 'tk', 'tlh-Latn', 'tlh-Piqd', 'tn', 'to', 'tr', 'tt', 'ty', 'ug', 'uk', 'ur', 'uz', 'vi', 'xh', 'yo', 'yua', 'yue', 'zh-Hans', 'zh-Hant', 'zu']

# %%
print(reverse_language_names)
# Out:
# {'Afrikaans': 'af', 'Amharic': 'am', 'Arabic': 'ar', 'Assamese': 'as', 'Azerbaijani': 'az', 'Bashkir': 'ba', 'Bulgarian': 'bg', 'Bhojpuri': 'bho', 'Bangla': 'bn', 'Tibetan': 'bo', 'Bodo': 'brx', 'Bosnian': 'bs', 'Catalan': 'ca', 'Czech': 'cs', 'Welsh': 'cy', 'Danish': 'da', 'German': 'de', 'Dogri': 'doi', 'Lower Sorbian': 'dsb', 'Divehi': 'dv', 'Greek': 'el', 'English': 'en', 'Spanish': 'es', 'Estonian': 'et', 'Basque': 'eu', 'Persian': 'fa', 'Finnish': 'fi', 'Filipino': 'fil', 'Fijian': 'fj', 'Faroese': 'fo', 'French': 'fr', 'French (Canada)': 'fr-CA', 'Irish': 'ga', 'Galician': 'gl', 'Konkani': 'gom', 'Gujarati': 'gu', 'Hausa': 'ha', 'Hebrew': 'he', 'Hindi': 'hi', 'Chhattisgarhi': 'hne', 'Croatian': 'hr', 'Upper Sorbian': 'hsb', 'Haitian Creole': 'ht', 'Hungarian': 'hu', 'Armenian': 'hy', 'Indonesian': 'id', 'Igbo': 'ig', 'Inuinnaqtun': 'ikt', 'Icelandic': 'is', 'Italian': 'it', 'Inuktitut': 'iu', 'Inuktitut (Latin)': 'iu-Latn', 'Japanese': 'ja', 'Georgian': 'ka', 'Kazakh': 'kk', 'Khmer': 'km', 'Kurdish (Northern)': 'kmr', 'Kannada': 'kn', 'Korean': 'ko', 'Kashmiri': 'ks', 'Kurdish (Central)': 'ku', 'Kyrgyz': 'ky', 'Lingala': 'ln', 'Lao': 'lo', 'Lithuanian': 'lt', 'Ganda': 'lug', 'Latvian': 'lv', 'Chinese (Literary)': 'lzh', 'Maithili': 'mai', 'Malagasy': 'mg', 'Māori': 'mi', 'Macedonian': 'mk', 'Malayalam': 'ml', 'Mongolian (Cyrillic)': 'mn-Cyrl', 'Mongolian (Traditional)': 'mn-Mong', 'Manipuri': 'mni', 'Marathi': 'mr', 'Malay': 'ms', 'Maltese': 'mt', 'Hmong Daw': 'mww', 'Myanmar (Burmese)': 'my', 'Norwegian': 'nb', 'Nepali': 'ne', 'Dutch': 'nl', 'Sesotho sa Leboa': 'nso', 'Nyanja': 'nya', 'Odia': 'or', 'Querétaro Otomi': 'otq', 'Punjabi': 'pa', 'Polish': 'pl', 'Dari': 'prs', 'Pashto': 'ps', 'Portuguese (Brazil)': 'pt', 'Portuguese (Portugal)': 'pt-PT', 'Romanian': 'ro', 'Russian': 'ru', 'Rundi': 'run', 'Kinyarwanda': 'rw', 'Sindhi': 'sd', 'Sinhala': 'si', 'Slovak': 'sk', 'Slovenian': 'sl', 'Samoan': 'sm', 'Shona': 'sn', 'Somali': 'so', 'Albanian': 'sq', 'Serbian (Cyrillic)': 'sr-Cyrl', 'Serbian (Latin)': 'sr-Latn', 'Sesotho': 'st', 'Swedish': 'sv', 'Swahili': 'sw', 'Tamil': 'ta', 'Telugu': 'te', 'Thai': 'th', 'Tigrinya': 'ti', 'Turkmen': 'tk', 'Klingon (Latin)': 'tlh-Latn', 'Klingon (pIqaD)': 'tlh-Piqd', 'Setswana': 'tn', 'Tongan': 'to', 'Turkish': 'tr', 'Tatar': 'tt', 'Tahitian': 'ty', 'Uyghur': 'ug', 'Ukrainian': 'uk', 'Urdu': 'ur', 'Uzbek (Latin)': 'uz', 'Vietnamese': 'vi', 'Xhosa': 'xh', 'Yoruba': 'yo', 'Yucatec Maya': 'yua', 'Cantonese (Traditional)': 'yue', 'Chinese Simplified': 'zh-Hans', 'Chinese Traditional': 'zh-Hant', 'Zulu': 'zu'}

# %%
print(f"Number of supported languages with Azure AI Translator = {len(reverse_language_names)}")
# Out:
# Number of supported languages with Azure AI Translator = 135

# %%
def get_language_code(language_name):
    """
    Function to get language code by language name
    Input: language full name
    Output: language code name
    """
    return reverse_language_names.get(language_name)

# %% [markdown]
# ### 3.1 Test

# %%
# Test
print(get_language_code("English"))
# Out:
# en

# %% [markdown]
# ## 4.1 Translation

# %%
def azure_ai_translator(mytext, source_lang, target_lang):
    """
    Translates text from one language to another using Azure AI Translator.
    
    Args:
        mytext (str): The text to be translated.
        source_lang (str): The full name of the source language.
        target_lang (str): The full name of the target language.
    
    Returns:
        str: The translated text, or None if an error occurs.
    """
    try:
        credential = AzureKeyCredential(azure_ai_translator_key)
        
        text_translator = TextTranslationClient(
            credential=credential, region=azure_ai_translator_region)
        input_text_elements = [mytext]

        # Get language codes
        source_lang_code = get_language_code(source_lang)
        target_lang_code = [get_language_code(target_lang)]
        
        # Response
        response = text_translator.translate(body=input_text_elements,
                                             to_language=target_lang_code)
        translation = response[0] if response else None

        if translation:
            detected_language = translation.detected_language
            if detected_language:
                print(f"Detected languages of the input text: {detected_language.language} with score = {detected_language.score}.")
            for translated_text in translation.translations:
                print(f"\nText to translate to: '{translated_text.to}'")
            return translated_text.text

    except HttpResponseError as exception:
        if exception.error is not None:
            print(f"Error Code: {exception.error.code}")
            print(f"Message: {exception.error.message}")

# %% [markdown]
# ### 4.1 Test

# %%
# Quick Test
result = azure_ai_translator("Welcome to this presentation", "English", "German")
print(result)
# Out:
# Detected languages of the input text: en with score = 1.0.
#
# Text to translate to: 'de'
# Willkommen zu dieser Präsentation

# %% [markdown]
# ### 5. STT and Translation

# %%
def stt_and_translation(audio_filename, source_lang, target_lang):
    """
    Speech to Text and translation using the STT transcript
    """
    try:
        # Speech to text result
        transcript = speech_to_text_whisper(audio_filename)
        # Translation of the Speech to text result
        translation = azure_ai_translator(transcript, source_lang, target_lang)
        
        return transcript, translation
    
    except Exception as e:
        print(f"[Error] Speech to text and translation error: {e}")
        
        return None, None

# %% [markdown]
# ### 5.1 Test

# %%
# Test
transcript, translation = stt_and_translation(audio_filename, "English", "Spanish")

transcript, translation
# Out:
# Detected languages of the input text: en with score = 1.0.
#
# Text to translate to: 'es'
# ('Hello. How are you today?', 'Hola. ¿Cómo te va?')

# %% [markdown]
# ### 5.2 Speech to Text and Translation using a webapp

# %%
image_url = "https://github.com/retkowsky/azure-ai-translator/blob/main/logotranslate.png?raw=true"
logo = "<center> <img src= {} width=200px></center>".format(image_url)
title = "Vocal translator using Azure AI services"
theme = "JohnSmith9982/small_and_pretty"  # https://huggingface.co/spaces/gradio/theme-gallery

translator_webapp = gr.Interface(
    stt_and_translation,
    inputs=[
        gr.components.Audio(
            sources="microphone", 
            type="filepath",
            label="Audio recording"
        ),
        gr.components.Dropdown(
            label="Audio source language",
            value="French",
            choices=language_full_names
        ),
        gr.components.Dropdown(
            label="Text target language",
            value="English",
            choices=language_full_names
        ),
    ],
    outputs=[
        gr.Text(label="Source text"),
        gr.Text(label="Translated text"),
    ],
    cache_examples=False,
    title=title,
    description=logo,
    #theme=theme,
)

# %%
translator_webapp.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * Running on public URL: https://d4efac49c85d0bb66a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d4efac49c85d0bb66a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Detected languages of the input text: fr with score = 1.0.
#
# Text to translate to: 'en'
