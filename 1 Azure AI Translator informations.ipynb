# %% [markdown]
# # Azure AI Translator informations
# https://learn.microsoft.com/en-us/azure/ai-services/translator/translator-overview
#
# <img src="https://github.com/retkowsky/azure-ai-translator/blob/main/logo.jpg?raw=true" width=200>

# %%
# %pip install azure-ai-translation-text==1.0.0b1

# %%
import datetime
import pandas as pd
import sys

from azure.ai.translation.text import TextTranslationClient, TranslatorCredential
from azure.ai.translation.text.models import InputTextItem
from azure.core.exceptions import HttpResponseError
from dotenv import load_dotenv

# %%
sys.version
# Out:
# '3.10.11 (main, May 16 2023, 00:28:57) [GCC 11.2.0]'

# %%
print(f"Today is {datetime.datetime.today().strftime('%d-%b-%Y %H:%M:%S')}")
# Out:
# Today is 11-Apr-2024 12:31:24

# %% [markdown]
# ## Azure AI Translator credentials

# %%
load_dotenv("azure.env")

azure_ai_translator_key = os.getenv("AZURE_AI_TRANSLATION_KEY")
azure_ai_translator_endpoint = os.getenv("AZURE_AI_TRANSLATION_ENDPOINT")
azure_ai_translator_region = os.getenv("AZURE_AI_TRANSLATION_REGION")

# %%
credential = TranslatorCredential(azure_ai_translator_key, azure_ai_translator_region)
text_translator = TextTranslationClient(
    endpoint=azure_ai_translator_endpoint, credential=credential)

# %% [markdown]
# ## Informations

# %%
# %%javascript Python
# OutputArea.auto_scroll_threshold = 9999

# %%
try:
    response = text_translator.get_languages()

    print(
        f"Number of supported languages for translate operation: {len(response.translation) if response.translation is not None else 0}"
    )
    print(
        f"Number of supported languages for transliterate operation: {len(response.transliteration) if response.transliteration is not None else 0}"
    )
    print(
        f"Number of supported languages for dictionary operations: {len(response.dictionary) if response.dictionary is not None else 0}"
    )

    print()

    if response.translation is not None:
        print("Translation Languages:")
        i = 1
        for key, value in response.translation.items():
            print(f"{i} {key} -- name: {value.name} ({value.native_name})")
            i += 1
    print()

    if response.transliteration is not None:
        print("Transliteration Languages:")
        i = 1
        for key, value in response.transliteration.items():
            print(
                f"{i} {key} -- name: {value.name}, supported script count: {len(value.scripts)}")
            i += 1
    print()

    if response.dictionary is not None:
        print("Dictionary Languages:")
        i = 1
        for key, value in response.dictionary.items():
            print(
                f"{i} {key} -- name: {value.name}, supported target languages count: {len(value.translations)}")
            i += 1

except HttpResponseError as exception:
    if exception.error is not None:
        print(f"Error Code: {exception.error.code}")
        print(f"Message: {exception.error.message}")
    raise
# Out:
# Number of supported languages for translate operation: 135
# Number of supported languages for transliterate operation: 42
# Number of supported languages for dictionary operations: 50
#
# Translation Languages:
# 1 af -- name: Afrikaans (Afrikaans)
# 2 am -- name: Amharic (አማርኛ)
# 3 ar -- name: Arabic (العربية)
# 4 as -- name: Assamese (অসমীয়া)
# 5 az -- name: Azerbaijani (Azərbaycan)
# 6 ba -- name: Bashkir (Bashkir)
# 7 bg -- name: Bulgarian (Български)
# 8 bho -- name: Bhojpuri (Bhojpuri)
# 9 bn -- name: Bangla (বাংলা)
# 10 bo -- name: Tibetan (བོད་སྐད་)
# 11 brx -- name: Bodo (बड़ो)
# 12 bs -- name: Bosnian (Bosnian)
# 13 ca -- name: Catalan (Català)
# 14 cs -- name: Czech (Čeština)
# 15 cy -- name: Welsh (Cymraeg)
# 16 da -- name: Danish (Dansk)
# 17 de -- name: German (Deutsch)
# 18 doi -- name: Dogri (Dogri)
# 19 dsb -- name: Lower Sorbian (Dolnoserbšćina)
# 20 dv -- name: Divehi (ދިވެހިބަސް)
# 21 el -- name: Greek (Ελληνικά)
# 22 en -- name: English (English)
# 23 es -- name: Spanish (Español)
# 24 et -- name: Estonian (Eesti)
# 25 eu -- name: Basque (Euskara)
# 26 fa -- name: Persian (فارسی)
# 27 fi -- name: Finnish (Suomi)
# 28 fil -- name: Filipino (Filipino)
# 29 fj -- name: Fijian (Na Vosa Vakaviti)
# 30 fo -- name: Faroese (Føroyskt)
# 31 fr -- name: French (Français)
# 32 fr-CA -- name: French (Canada) (Français (Canada))
# 33 ga -- name: Irish (Gaeilge)
# 34 gl -- name: Galician (Galego)
# 35 gom -- name: Konkani (Konkani)
# 36 gu -- name: Gujarati (ગુજરાતી)
# 37 ha -- name: Hausa (Hausa)
# 38 he -- name: Hebrew (עברית)
# 39 hi -- name: Hindi (हिन्दी)
# 40 hne -- name: Chhattisgarhi (Chhattisgarhi)
# 41 hr -- name: Croatian (Hrvatski)
# 42 hsb -- name: Upper Sorbian (Hornjoserbšćina)
# 43 ht -- name: Haitian Creole (Haitian Creole)
# 44 hu -- name: Hungarian (Magyar)
# 45 hy -- name: Armenian (Հայերեն)
# 46 id -- name: Indonesian (Indonesia)
# 47 ig -- name: Igbo (Ásụ̀sụ́ Ìgbò)
# 48 ikt -- name: Inuinnaqtun (Inuinnaqtun)
# 49 is -- name: Icelandic (Íslenska)
# 50 it -- name: Italian (Italiano)
# 51 iu -- name: Inuktitut (ᐃᓄᒃᑎᑐᑦ)
# 52 iu-Latn -- name: Inuktitut (Latin) (Inuktitut (Latin))
# 53 ja -- name: Japanese (日本語)
# 54 ka -- name: Georgian (ქართული)
# 55 kk -- name: Kazakh (Қазақ Тілі)
# 56 km -- name: Khmer (ខ្មែរ)
# 57 kmr -- name: Kurdish (Northern) (Kurdî (Bakur))
# 58 kn -- name: Kannada (ಕನ್ನಡ)
# 59 ko -- name: Korean (한국어)
# 60 ks -- name: Kashmiri (کٲشُر)
# 61 ku -- name: Kurdish (Central) (Kurdî (Navîn))
# 62 ky -- name: Kyrgyz (Кыргызча)
# 63 ln -- name: Lingala (Lingála)
# 64 lo -- name: Lao (ລາວ)
# 65 lt -- name: Lithuanian (Lietuvių)
# 66 lug -- name: Ganda (Ganda)
# 67 lv -- name: Latvian (Latviešu)
# 68 lzh -- name: Chinese (Literary) (中文 (文言文))
# 69 mai -- name: Maithili (Maithili)
# 70 mg -- name: Malagasy (Malagasy)
# 71 mi -- name: Māori (Te Reo Māori)
# 72 mk -- name: Macedonian (Македонски)
# 73 ml -- name: Malayalam (മലയാളം)
# 74 mn-Cyrl -- name: Mongolian (Cyrillic) (Mongolian (Cyrillic))
# 75 mn-Mong -- name: Mongolian (Traditional) (ᠮᠣᠩᠭᠣᠯ ᠬᠡᠯᠡ)
# 76 mni -- name: Manipuri (ꯃꯩꯇꯩꯂꯣꯟ)
# 77 mr -- name: Marathi (मराठी)
# 78 ms -- name: Malay (Melayu)
# 79 mt -- name: Maltese (Malti)
# 80 mww -- name: Hmong Daw (Hmong Daw)
# 81 my -- name: Myanmar (Burmese) (မြန်မာ)
# 82 nb -- name: Norwegian (Norsk Bokmål)
# 83 ne -- name: Nepali (नेपाली)
# 84 nl -- name: Dutch (Nederlands)
# 85 nso -- name: Sesotho sa Leboa (Sesotho sa Leboa)
# 86 nya -- name: Nyanja (Nyanja)
# 87 or -- name: Odia (ଓଡ଼ିଆ)
# 88 otq -- name: Querétaro Otomi (Hñähñu)
# 89 pa -- name: Punjabi (ਪੰਜਾਬੀ)
# 90 pl -- name: Polish (Polski)
# 91 prs -- name: Dari (دری)
# 92 ps -- name: Pashto (پښتو)
# 93 pt -- name: Portuguese (Brazil) (Português (Brasil))
# 94 pt-PT -- name: Portuguese (Portugal) (Português (Portugal))
# 95 ro -- name: Romanian (Română)
# 96 ru -- name: Russian (Русский)
# 97 run -- name: Rundi (Rundi)
# 98 rw -- name: Kinyarwanda (Kinyarwanda)
# 99 sd -- name: Sindhi (سنڌي)
# 100 si -- name: Sinhala (සිංහල)
# 101 sk -- name: Slovak (Slovenčina)
# 102 sl -- name: Slovenian (Slovenščina)
# 103 sm -- name: Samoan (Gagana Sāmoa)
# 104 sn -- name: Shona (chiShona)
# 105 so -- name: Somali (Soomaali)
# 106 sq -- name: Albanian (Shqip)
# 107 sr-Cyrl -- name: Serbian (Cyrillic) (Српски (ћирилица))
# 108 sr-Latn -- name: Serbian (Latin) (Srpski (latinica))
# 109 st -- name: Sesotho (Sesotho)
# 110 sv -- name: Swedish (Svenska)
# 111 sw -- name: Swahili (Kiswahili)
# 112 ta -- name: Tamil (தமிழ்)
# 113 te -- name: Telugu (తెలుగు)
# 114 th -- name: Thai (ไทย)
# 115 ti -- name: Tigrinya (ትግር)
# 116 tk -- name: Turkmen (Türkmen Dili)
# 117 tlh-Latn -- name: Klingon (Latin) (Klingon (Latin))
# 118 tlh-Piqd -- name: Klingon (pIqaD) (Klingon (pIqaD))
# 119 tn -- name: Setswana (Setswana)
# 120 to -- name: Tongan (Lea Fakatonga)
# 121 tr -- name: Turkish (Türkçe)
# 122 tt -- name: Tatar (Татар)
# 123 ty -- name: Tahitian (Reo Tahiti)
# 124 ug -- name: Uyghur (ئۇيغۇرچە)
# 125 uk -- name: Ukrainian (Українська)
# 126 ur -- name: Urdu (اردو)
# 127 uz -- name: Uzbek (Latin) (Uzbek (Latin))
# 128 vi -- name: Vietnamese (Tiếng Việt)
# 129 xh -- name: Xhosa (isiXhosa)
# 130 yo -- name: Yoruba (Èdè Yorùbá)
# 131 yua -- name: Yucatec Maya (Yucatec Maya)
# 132 yue -- name: Cantonese (Traditional) (粵語 (繁體))
# 133 zh-Hans -- name: Chinese Simplified (中文 (简体))
# 134 zh-Hant -- name: Chinese Traditional (繁體中文 (繁體))
# 135 zu -- name: Zulu (Isi-Zulu)
#
# Transliteration Languages:
# 1 ar -- name: Arabic, supported script count: 2
# 2 as -- name: Assamese, supported script count: 2
# 3 be -- name: Belarusian, supported script count: 2
# 4 bg -- name: Bulgarian, supported script count: 2
# 5 bn -- name: Bangla, supported script count: 2
# 6 brx -- name: Bodo, supported script count: 2
# 7 el -- name: Greek, supported script count: 2
# 8 fa -- name: Persian, supported script count: 2
# 9 gom -- name: Konkani, supported script count: 2
# 10 gu -- name: Gujarati, supported script count: 2
# 11 he -- name: Hebrew, supported script count: 2
# 12 hi -- name: Hindi, supported script count: 2
# 13 ja -- name: Japanese, supported script count: 2
# 14 kk -- name: Kazakh, supported script count: 2
# 15 kn -- name: Kannada, supported script count: 2
# 16 ko -- name: Korean, supported script count: 2
# 17 ks -- name: Kashmiri, supported script count: 2
# 18 ky -- name: Kyrgyz, supported script count: 2
# 19 mai -- name: Maithili, supported script count: 2
# 20 mk -- name: Macedonian, supported script count: 2
# 21 ml -- name: Malayalam, supported script count: 2
# 22 mn-Cyrl -- name: Mongolian (Cyrillic), supported script count: 2
# 23 mni -- name: Manipuri, supported script count: 2
# 24 mr -- name: Marathi, supported script count: 2
# 25 ne -- name: Nepali, supported script count: 2
# 26 or -- name: Odia, supported script count: 2
# 27 pa -- name: Punjabi, supported script count: 2
# 28 ru -- name: Russian, supported script count: 2
# 29 sa -- name: Sanskrit, supported script count: 2
# 30 sd -- name: Sindhi, supported script count: 2
# 31 si -- name: Sinhala, supported script count: 2
# 32 sr-Cyrl -- name: Serbian (Cyrillic), supported script count: 1
# 33 sr-Latn -- name: Serbian (Latin), supported script count: 1
# 34 ta -- name: Tamil, supported script count: 2
# 35 te -- name: Telugu, supported script count: 2
# 36 tg -- name: Tajik, supported script count: 2
# 37 th -- name: Thai, supported script count: 1
# 38 tt -- name: Tatar, supported script count: 2
# 39 uk -- name: Ukrainian, supported script count: 2
# 40 ur -- name: Urdu, supported script count: 2
# 41 zh-Hans -- name: Chinese Simplified, supported script count: 2
# 42 zh-Hant -- name: Chinese Traditional, supported script count: 2
#
# Dictionary Languages:
# 1 af -- name: Afrikaans, supported target languages count: 1
# 2 ar -- name: Arabic, supported target languages count: 1
# 3 bg -- name: Bulgarian, supported target languages count: 1
# 4 bn -- name: Bangla, supported target languages count: 1
# 5 bs -- name: Bosnian, supported target languages count: 1
# 6 ca -- name: Catalan, supported target languages count: 1
# 7 cs -- name: Czech, supported target languages count: 1
# 8 cy -- name: Welsh, supported target languages count: 1
# 9 da -- name: Danish, supported target languages count: 1
# 10 de -- name: German, supported target languages count: 1
# 11 el -- name: Greek, supported target languages count: 1
# 12 en -- name: English, supported target languages count: 49
# 13 es -- name: Spanish, supported target languages count: 1
# 14 et -- name: Estonian, supported target languages count: 1
# 15 fa -- name: Persian, supported target languages count: 1
# 16 fi -- name: Finnish, supported target languages count: 1
# 17 fr -- name: French, supported target languages count: 1
# 18 he -- name: Hebrew, supported target languages count: 1
# 19 hi -- name: Hindi, supported target languages count: 1
# 20 hr -- name: Croatian, supported target languages count: 1
# 21 hu -- name: Hungarian, supported target languages count: 1
# 22 id -- name: Indonesian, supported target languages count: 1
# 23 is -- name: Icelandic, supported target languages count: 1
# 24 it -- name: Italian, supported target languages count: 1
# 25 ja -- name: Japanese, supported target languages count: 1
# 26 ko -- name: Korean, supported target languages count: 1
# 27 lt -- name: Lithuanian, supported target languages count: 1
# 28 lv -- name: Latvian, supported target languages count: 1
# 29 ms -- name: Malay, supported target languages count: 1
# 30 mt -- name: Maltese, supported target languages count: 1
# 31 mww -- name: Hmong Daw, supported target languages count: 1
# 32 nb -- name: Norwegian, supported target languages count: 1
# 33 nl -- name: Dutch, supported target languages count: 1
# 34 pl -- name: Polish, supported target languages count: 1
# 35 pt -- name: Portuguese (Brazil), supported target languages count: 1
# 36 ro -- name: Romanian, supported target languages count: 1
# 37 ru -- name: Russian, supported target languages count: 1
# 38 sk -- name: Slovak, supported target languages count: 1
# 39 sl -- name: Slovenian, supported target languages count: 1
# 40 sr-Latn -- name: Serbian (Latin), supported target languages count: 1
# 41 sv -- name: Swedish, supported target languages count: 1
# 42 sw -- name: Swahili, supported target languages count: 1
# 43 ta -- name: Tamil, supported target languages count: 1
# 44 th -- name: Thai, supported target languages count: 1
# 45 tlh-Latn -- name: Klingon (Latin), supported target languages count: 1
# 46 tr -- name: Turkish, supported target languages count: 1
# 47 uk -- name: Ukrainian, supported target languages count: 1
# 48 ur -- name: Urdu, supported target languages count: 1
# 49 vi -- name: Vietnamese, supported target languages count: 1
# 50 zh-Hans -- name: Chinese Simplified, supported target languages count: 1

# %%
try:
    accept_language = "fr"
    response = text_translator.get_languages(accept_language=accept_language)

    print(
        f"Number of supported languages for translate operation: {len(response.translation) if response.translation is not None else 0}"
    )
    print(
        f"Number of supported languages for transliterate operation: {len(response.transliteration) if response.transliteration is not None else 0}"
    )
    print(
        f"Number of supported languages for dictionary operations: {len(response.dictionary) if response.dictionary is not None else 0}"
    )

    print()
    if response.translation is not None:
        print("Translation Languages:")
        i = 1
        for key, value in response.translation.items():
            print(f"{i} {key} -- name: {value.name} ({value.native_name})")
            i += 1

    if response.transliteration is not None:
        print("Transliteration Languages:")
        i = 0
        for key, value in response.transliteration.items():
            print(
                f"{i} {key} -- name: {value.name}, supported script count: {len(value.scripts)}")
            i += 1

    if response.dictionary is not None:
        i = 0
        print("Dictionary Languages:")
        for key, value in response.dictionary.items():
            print(
                f"{i} {key} -- name: {value.name}, supported target languages count: {len(value.translations)}")
            i += 1

except HttpResponseError as exception:
    if exception.error is not None:
        print(f"Error Code: {exception.error.code}")
        print(f"Message: {exception.error.message}")
    raise
# Out:
# Number of supported languages for translate operation: 135
# Number of supported languages for transliterate operation: 42
# Number of supported languages for dictionary operations: 50
#
# Translation Languages:
# 1 af -- name: Afrikaans (Afrikaans)
# 2 am -- name: Amharique (አማርኛ)
# 3 ar -- name: Arabe (العربية)
# 4 as -- name: Assamais (অসমীয়া)
# 5 az -- name: Azerbaïdjanais (Azərbaycan)
# 6 ba -- name: Bachkir (Bashkir)
# 7 bg -- name: Bulgare (Български)
# 8 bho -- name: Bhojpuri (Bhojpuri)
# 9 bn -- name: Bengali (বাংলা)
# 10 bo -- name: Tibétain (བོད་སྐད་)
# 11 brx -- name: Bodo (बड़ो)
# 12 bs -- name: Bosniaque (Bosnian)
# 13 ca -- name: Catalan (Català)
# 14 cs -- name: Tchèque (Čeština)
# 15 cy -- name: Gallois (Cymraeg)
# 16 da -- name: Danois (Dansk)
# 17 de -- name: Allemand (Deutsch)
# 18 doi -- name: Dogri (Dogri)
# 19 dsb -- name: Bas-Sorabe (Dolnoserbšćina)
# 20 dv -- name: Maldivien (ދިވެހިބަސް)
# 21 el -- name: Grec (Ελληνικά)
# 22 en -- name: Anglais (English)
# 23 es -- name: Espagnol (Español)
# 24 et -- name: Estonien (Eesti)
# 25 eu -- name: Basque (Euskara)
# 26 fa -- name: Persan (فارسی)
# 27 fi -- name: Finnois (Suomi)
# 28 fil -- name: Filipino (Filipino)
# 29 fj -- name: Fidjien (Na Vosa Vakaviti)
# 30 fo -- name: Féroïen (Føroyskt)
# 31 fr -- name: Français (Français)
# 32 fr-CA -- name: Français (Canada) (Français (Canada))
# 33 ga -- name: Irlandais (Gaeilge)
# 34 gl -- name: Galicien (Galego)
# 35 gom -- name: Konkani (Konkani)
# 36 gu -- name: Goudjarati (ગુજરાતી)
# 37 ha -- name: Haoussa (Hausa)
# 38 he -- name: Hébreu (עברית)
# 39 hi -- name: Hindi (हिन्दी)
# 40 hne -- name: Chhattisgarhi (Chhattisgarhi)
# 41 hr -- name: Croate (Hrvatski)
# 42 hsb -- name: Haut-Sorabe (Hornjoserbšćina)
# 43 ht -- name: Créole Haïtien (Haitian Creole)
# 44 hu -- name: Hongrois (Magyar)
# 45 hy -- name: Arménien (Հայերեն)
# 46 id -- name: Indonésien (Indonesia)
# 47 ig -- name: Igbo (Ásụ̀sụ́ Ìgbò)
# 48 ikt -- name: Inuinnaqtun (Inuinnaqtun)
# 49 is -- name: Islandais (Íslenska)
# 50 it -- name: Italien (Italiano)
# 51 iu -- name: Inuktitut (ᐃᓄᒃᑎᑐᑦ)
# 52 iu-Latn -- name: Inuktitut (Latin) (Inuktitut (Latin))
# 53 ja -- name: Japonais (日本語)
# 54 ka -- name: Géorgien (ქართული)
# 55 kk -- name: Kazakh (Қазақ Тілі)
# 56 km -- name: Khmer (ខ្មែរ)
# 57 kmr -- name: Kurde (septentrional) (Kurdî (Bakur))
# 58 kn -- name: Kannada (ಕನ್ನಡ)
# 59 ko -- name: Coréen (한국어)
# 60 ks -- name: Kashmiri (کٲشُر)
# 61 ku -- name: Kurde (central) (Kurdî (Navîn))
# 62 ky -- name: Kirghize (Кыргызча)
# 63 ln -- name: Lingala (Lingála)
# 64 lo -- name: Lao (ລາວ)
# 65 lt -- name: Lituanien (Lietuvių)
# 66 lug -- name: Ganda (Ganda)
# 67 lv -- name: Letton (Latviešu)
# 68 lzh -- name: Chinese (Literary) (中文 (文言文))
# 69 mai -- name: Maïthili (Maithili)
# 70 mg -- name: Malgache (Malagasy)
# 71 mi -- name: Maori (Te Reo Māori)
# 72 mk -- name: Macédonien (Македонски)
# 73 ml -- name: Malayalam (മലയാളം)
# 74 mn-Cyrl -- name: Mongolian (Cyrillic) (Mongolian (Cyrillic))
# 75 mn-Mong -- name: Mongolian (Traditional) (ᠮᠣᠩᠭᠣᠯ ᠬᠡᠯᠡ)
# 76 mni -- name: Manipuri (ꯃꯩꯇꯩꯂꯣꯟ)
# 77 mr -- name: Marathi (मराठी)
# 78 ms -- name: Malais (Melayu)
# 79 mt -- name: Maltais (Malti)
# 80 mww -- name: Hmong (Hmong Daw)
# 81 my -- name: Birman (မြန်မာ)
# 82 nb -- name: Norvégien Bokmål (Norsk Bokmål)
# 83 ne -- name: Népalais (नेपाली)
# 84 nl -- name: Néerlandais (Nederlands)
# 85 nso -- name: Sesotho sa Leboa (Sesotho sa Leboa)
# 86 nya -- name: Nyanja (Nyanja)
# 87 or -- name: Odia (ଓଡ଼ିଆ)
# 88 otq -- name: Otomi De Querétaro (Hñähñu)
# 89 pa -- name: Pendjabi (ਪੰਜਾਬੀ)
# 90 pl -- name: Polonais (Polski)
# 91 prs -- name: Dari (دری)
# 92 ps -- name: Pachto (پښتو)
# 93 pt -- name: Portugais (Brésil) (Português (Brasil))
# 94 pt-PT -- name: Portugais (Portugal) (Português (Portugal))
# 95 ro -- name: Roumain (Română)
# 96 ru -- name: Russe (Русский)
# 97 run -- name: Rundi (Rundi)
# 98 rw -- name: Kinyarwanda (Kinyarwanda)
# 99 sd -- name: Sindhi (سنڌي)
# 100 si -- name: Cingalais (සිංහල)
# 101 sk -- name: Slovaque (Slovenčina)
# 102 sl -- name: Slovène (Slovenščina)
# 103 sm -- name: Samoan (Gagana Sāmoa)
# 104 sn -- name: Shona (chiShona)
# 105 so -- name: Somali (Soomaali)
# 106 sq -- name: Albanais (Shqip)
# 107 sr-Cyrl -- name: Serbe (Cyrillique) (Српски (ћирилица))
# 108 sr-Latn -- name: Serbe (Latin) (Srpski (latinica))
# 109 st -- name: Sesotho (Sesotho)
# 110 sv -- name: Suédois (Svenska)
# 111 sw -- name: Swahili (Kiswahili)
# 112 ta -- name: Tamoul (தமிழ்)
# 113 te -- name: Télougou (తెలుగు)
# 114 th -- name: Thaï (ไทย)
# 115 ti -- name: Tigrigna (ትግር)
# 116 tk -- name: Turkmène (Türkmen Dili)
# 117 tlh-Latn -- name: Klingon (Latin) (Klingon (Latin))
# 118 tlh-Piqd -- name: Klingon (pIqaD) (Klingon (pIqaD))
# 119 tn -- name: Setswana (Setswana)
# 120 to -- name: Tongien (Lea Fakatonga)
# 121 tr -- name: Turc (Türkçe)
# 122 tt -- name: Tatar (Татар)
# 123 ty -- name: Tahitien (Reo Tahiti)
# 124 ug -- name: Ouïghour (ئۇيغۇرچە)
# 125 uk -- name: Ukrainien (Українська)
# 126 ur -- name: Ourdou (اردو)
# 127 uz -- name: Ouzbek (Uzbek (Latin))
# 128 vi -- name: Vietnamien (Tiếng Việt)
# 129 xh -- name: Xhosa (isiXhosa)
# 130 yo -- name: Yoruba (Èdè Yorùbá)
# 131 yua -- name: Maya Yucatèque (Yucatec Maya)
# 132 yue -- name: Cantonais (Traditionnel) (粵語 (繁體))
# 133 zh-Hans -- name: Chinois (Simplifié) (中文 (简体))
# 134 zh-Hant -- name: Chinois (Traditionnel) (繁體中文 (繁體))
# 135 zu -- name: Zoulou (Isi-Zulu)
# Transliteration Languages:
# 0 ar -- name: Arabe, supported script count: 2
# 1 as -- name: Assamais, supported script count: 2
# 2 be -- name: Biélorusse, supported script count: 2
# 3 bg -- name: Bulgare, supported script count: 2
# 4 bn -- name: Bengali, supported script count: 2
# 5 brx -- name: Bodo, supported script count: 2
# 6 el -- name: Grec, supported script count: 2
# 7 fa -- name: Persan, supported script count: 2
# 8 gom -- name: Konkani, supported script count: 2
# 9 gu -- name: Goudjarati, supported script count: 2
# 10 he -- name: Hébreu, supported script count: 2
# 11 hi -- name: Hindi, supported script count: 2
# 12 ja -- name: Japonais, supported script count: 2
# 13 kk -- name: Kazakh, supported script count: 2
# 14 kn -- name: Kannada, supported script count: 2
# 15 ko -- name: Coréen, supported script count: 2
# 16 ks -- name: Kashmiri, supported script count: 2
# 17 ky -- name: Kirghize, supported script count: 2
# 18 mai -- name: Maïthili, supported script count: 2
# 19 mk -- name: Macédonien, supported script count: 2
# 20 ml -- name: Malayalam, supported script count: 2
# 21 mn-Cyrl -- name: Mongolian (Cyrillic), supported script count: 2
# 22 mni -- name: Manipuri, supported script count: 2
# 23 mr -- name: Marathi, supported script count: 2
# 24 ne -- name: Népalais, supported script count: 2
# 25 or -- name: Odia, supported script count: 2
# 26 pa -- name: Pendjabi, supported script count: 2
# 27 ru -- name: Russe, supported script count: 2
# 28 sa -- name: Sanskrit, supported script count: 2
# 29 sd -- name: Sindhi, supported script count: 2
# 30 si -- name: Cingalais, supported script count: 2
# 31 sr-Cyrl -- name: Serbe (Cyrillique), supported script count: 1
# 32 sr-Latn -- name: Serbe (Latin), supported script count: 1
# 33 ta -- name: Tamoul, supported script count: 2
# 34 te -- name: Télougou, supported script count: 2
# 35 tg -- name: Tadjik, supported script count: 2
# 36 th -- name: Thaï, supported script count: 1
# 37 tt -- name: Tatar, supported script count: 2
# 38 uk -- name: Ukrainien, supported script count: 2
# 39 ur -- name: Ourdou, supported script count: 2
# 40 zh-Hans -- name: Chinois (Simplifié), supported script count: 2
# 41 zh-Hant -- name: Chinois (Traditionnel), supported script count: 2
# Dictionary Languages:
# 0 af -- name: Afrikaans, supported target languages count: 1
# 1 ar -- name: Arabe, supported target languages count: 1
# 2 bg -- name: Bulgare, supported target languages count: 1
# 3 bn -- name: Bengali, supported target languages count: 1
# 4 bs -- name: Bosnian, supported target languages count: 1
# 5 ca -- name: Catalan, supported target languages count: 1
# 6 cs -- name: Tchèque, supported target languages count: 1
# 7 cy -- name: Gallois, supported target languages count: 1
# 8 da -- name: Danois, supported target languages count: 1
# 9 de -- name: Allemand, supported target languages count: 1
# 10 el -- name: Grec, supported target languages count: 1
# 11 en -- name: Anglais, supported target languages count: 49
# 12 es -- name: Espagnol, supported target languages count: 1
# 13 et -- name: Estonien, supported target languages count: 1
# 14 fa -- name: Persan, supported target languages count: 1
# 15 fi -- name: Finnois, supported target languages count: 1
# 16 fr -- name: Français, supported target languages count: 1
# 17 he -- name: Hébreu, supported target languages count: 1
# 18 hi -- name: Hindi, supported target languages count: 1
# 19 hr -- name: Croate, supported target languages count: 1
# 20 hu -- name: Hongrois, supported target languages count: 1
# 21 id -- name: Indonésien, supported target languages count: 1
# 22 is -- name: Islandais, supported target languages count: 1
# 23 it -- name: Italien, supported target languages count: 1
# 24 ja -- name: Japonais, supported target languages count: 1
# 25 ko -- name: Coréen, supported target languages count: 1
# 26 lt -- name: Lituanien, supported target languages count: 1
# 27 lv -- name: Letton, supported target languages count: 1
# 28 ms -- name: Malais, supported target languages count: 1
# 29 mt -- name: Maltais, supported target languages count: 1
# 30 mww -- name: Hmong, supported target languages count: 1
# 31 nb -- name: Norvégien Bokmål, supported target languages count: 1
# 32 nl -- name: Néerlandais, supported target languages count: 1
# 33 pl -- name: Polonais, supported target languages count: 1
# 34 pt -- name: Portugais (Brésil), supported target languages count: 1
# 35 ro -- name: Roumain, supported target languages count: 1
# 36 ru -- name: Russe, supported target languages count: 1
# 37 sk -- name: Slovaque, supported target languages count: 1
# 38 sl -- name: Slovène, supported target languages count: 1
# 39 sr-Latn -- name: Serbe (Latin), supported target languages count: 1
# 40 sv -- name: Suédois, supported target languages count: 1
# 41 sw -- name: Swahili, supported target languages count: 1
# 42 ta -- name: Tamoul, supported target languages count: 1
# 43 th -- name: Thaï, supported target languages count: 1
# 44 tlh-Latn -- name: Klingon (Latin), supported target languages count: 1
# 45 tr -- name: Turc, supported target languages count: 1
# 46 uk -- name: Ukrainien, supported target languages count: 1
# 47 ur -- name: Ourdou, supported target languages count: 1
# 48 vi -- name: Vietnamien, supported target languages count: 1
# 49 zh-Hans -- name: Chinois (Simplifié), supported target languages count: 1

# %% [markdown]
# ## df

# %%
data = []

if response.translation is not None:
    for key, value in response.translation.items():
        data.append({'Language_Code': key,
                     'Language_Name': value.name,
                     'Native_Name': value.native_name})

df = pd.DataFrame(data)

# %%
df
# Out:
#     Language_Code             Language_Name   Native_Name
# 0              af                 Afrikaans     Afrikaans
# 1              am                 Amharique          አማርኛ
# 2              ar                     Arabe       العربية
# 3              as                  Assamais       অসমীয়া
# 4              az            Azerbaïdjanais    Azərbaycan
# ..            ...                       ...           ...
# 130           yua            Maya Yucatèque  Yucatec Maya
# 131           yue  Cantonais (Traditionnel)       粵語 (繁體)
# 132       zh-Hans       Chinois (Simplifié)       中文 (简体)
# 133       zh-Hant    Chinois (Traditionnel)     繁體中文 (繁體)
# 134            zu                    Zoulou      Isi-Zulu
#
# [135 rows x 3 columns]

# %%
df.shape
# Out:
# (135, 3)

# %%
df.to_excel("languages.xlsx")

# %%
# !ls languages.xlsx -lh
# Out:
# -rwxrwxrwx 1 root root 10K Apr 11 12:31 languages.xlsx

# %%
def get_language_name(langcode):
    # Get language name from its code
    langname = df.loc[df['Language_Code'] == langcode, 'Language_Name'].values[0]
    print(langcode, "=>", langname)
    
    return langname

# %%
get_language_name("fr")
# Out:
# fr => Français
# 'Français'

# %%
def get_language_code(langname):
    # get language code from its name
    langcode = df.loc[df['Language_Name'] == langname, 'Language_Code'].values[0]
    print(langname, "=>", langcode)
    
    return langcode

# %%
get_language_code("Français")
# Out:
# Français => fr
# 'fr'
